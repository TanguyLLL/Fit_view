# %% [markdown]
# # Regrouping Files
#
# This is the first notebook to run.
# It will list different tables and save them in a pandas Dataframe.
# Format will have to be adapted to allow the code to work with lower memory systems.
# **!!!!! WATCH !!!!!**
# If several months of data are available this notebook can take a long time to run!!!!
# But it has to run only once when the full data set is downloaded from fitbit

# %%
import json
import pandas as pd
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns
import ast
import numpy as np
import re
import _01_regroup_fitbit_data
import importlib
sns.set(style="darkgrid")
# %matplotlib inline

# %%
# Usefull paths : to adapt with local path where the data is stored
# This is the only data that has to be changed by the user
fitbit_path = '/Users/tanguylienart/Documents/raspberry_projects/data/Tanguy/user-site-export/'  # path to the user-site-export folder
data_path= '/Users/tanguylienart/Documents/raspberry_projects/data/'  # Path to the folder used to save the produced the data

# %%
importlib.reload(_01_regroup_fitbit_data)
_01_regroup_fitbit_data.regroup(fitbit_path, data_path)
# If files are not regrouped in any category, code print excluded files followed by the excluded file
# Out:
# Excluded file     weight-2017-05-22.json
# Excluded file     height-2017-05-22.json
# Excluded file     water_logs-0.json
# Excluded file     weight-2018-09-14.json
# Excluded file     badge.json
# -------------------- Builded categories and files per category  --------------------
# time_in_heart_rate_zones_files   813
#  resting_heart_rate_files   3
#  heart_rate_files   813
#  very_active_minutes_files   29
#  lightly_active_minutes_files   29
#  moderately_active_minutes_files   29
#  sedentary_minutes_files   29
#  steps_files   29
#  sleep_files   29
#  distance_files   29
#  calories_files   29
#  swim_lengths_data_files   14
#  altitude_files   14
#  exercise_files   7
#  demographic_files   3
#
# -------------------- Regroup resting hearbeat data into one dataframe  --------------------
# ////////// CHECK: amount of available rows = 3 //////////
# ////////// resting_heart_rate processed - size = (795, 3) //////////
#
#
#
# resting_heart_rate - SAVED
# ...
